# %%
from datetime import date, timedelta
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# preprocess visitors (training) to store / date
av = pd.read_csv('air_visit_data.csv', converters={'visitors': lambda u: np.log1p(float(u))}, parse_dates = ['visit_date'])
sample = pd.read_csv('sample_submission.csv')

# %%
istore = sample['id'].map(lambda x: '_'.join(x.split('_')[:2])).unique()
idate_test = sample['id'].map(lambda x: x.split('_')[2]).unique()
idate_train = pd.date_range(av['visit_date'].min(), av['visit_date'].max())
idate = pd.date_range(date(2016,1,1), date(2017,5,31))

# %%
df_train = av.set_index(['air_store_id', 'visit_date']).unstack(level = 1)
df_train.columns = df_train.columns.get_level_values(1)
df_train = df_train.reindex(idate_train.values, axis = 1).reindex(istore, axis = 0).fillna(0).astype('int')

# %%
# preprocess reserves (all) store / date
ares = pd.read_csv('air_reserve.csv',
                   parse_dates=['visit_datetime','reserve_datetime'])
hres = pd.read_csv('hpg_reserve.csv',
                   parse_dates=['visit_datetime','reserve_datetime'])
ahrel= pd.read_csv('store_id_relation.csv')

# %%
hres['air_store_id'] = hres['hpg_store_id'].map(ahrel.set_index('hpg_store_id')['air_store_id'])
hres = hres.drop('hpg_store_id', axis = 1).dropna()
res = pd.concat([ares,hres])
res['visit_date'] = res['visit_datetime'].dt.date
res = res.drop(['reserve_datetime', 'visit_datetime'], axis = 1).groupby(['air_store_id', 'visit_date']).sum().unstack(level = 1)
res.columns = res.columns.get_level_values(1)
res = res.reindex(idate, axis = 1).reindex(istore, axis = 0).fillna(0).astype('int')

# %%
# preprocess categorical features
## store: genre, lat, long
astore = pd.read_csv('air_store_info.csv')
astore = astore.set_index('air_store_id').reindex(istore).drop('air_area_name',axis = 1)

# %%
le = LabelEncoder()
astore['genre'] = le.fit_transform(astore['air_genre_name'])
astore.drop(['air_genre_name'], axis = 1, inplace = True)

# %%
## day: holiday, dow
dinfo = pd.read_csv('date_info.csv', parse_dates = ['calendar_date'])
ledow = LabelEncoder()
dinfo['dow'] = ledow.fit_transform(dinfo['day_of_week'])
dinfo.drop(['day_of_week'], axis = 1, inplace = True)
dinfo.set_index('calendar_date', inplace = True)

# %%
# predict day by day, using both MA and cat features

# %%
def get_timespan(df, dt, minus, periods, freq='D'): #slicing data by date, trace back "minus" days
    return df[pd.date_range(dt - timedelta(days=minus), periods=periods, freq=freq)]

# %%
def prepare_dataset(data, res, store, holi, t_anchor, is_train=True):
    # MA & time series
    X = pd.DataFrame({
        "median_30_2017": get_timespan(data, t_anchor, 30, 30).median(axis=1).values,
        "median_60_2017": get_timespan(data, t_anchor, 60, 60).median(axis=1).values,
        "median_140_2017": get_timespan(data, t_anchor, 140, 140).median(axis=1).values
    }, index = data.index)
    
    for i in range(1,15):
        X["day_{}_2017".format(i)] = get_timespan(data, t_anchor, i, 1).values.ravel()
        
    for i in range(15):
        X["res_{}_2017".format(i)] = get_timespan(res, t_anchor, i, 1).values.ravel()
    
    for i in range(7):
        X['sum_4_dow{}_2017'.format(i)] = get_timespan(data, t_anchor, 28-i, 4, freq='7D').sum(axis=1).values
        X['median_4_dow{}_2017'.format(i)] = get_timespan(data, t_anchor, 28-i, 4, freq='7D').median(axis=1).values
    
    # add genre, lat, long
    X = X.join(store)
    
    X_39 = []
    for i in range(39):
        day = t_anchor + timedelta(days = i)
        X_temp = X.join(pd.DataFrame([dinfo.loc[day].tolist()]*X.shape[0], columns = ['holiday', 'dow'], index = X.index))
        for i in range(15):
            X_temp['res_{}'.format(i)]= res[day-timedelta(days = i)]
        X_temp['mres_30_2017'] = get_timespan(res, day, 30, 30).median(axis=1).values
        X_temp['mres_60_2017'] = get_timespan(res, day, 60, 60).median(axis=1).values
        X_temp['mres_140_2017'] = get_timespan(res, day, 140, 140).median(axis=1).values
        X_39.append(X_temp)
    if is_train:
        y = data[pd.date_range(t_anchor, periods=39)].values
        return X_39, y
    return X_39

# %%
t2017 = date(2017, 1, 23)
X_l, y_l = [], []
for i in range(50):
    delta = timedelta(days=i)
    X_tmp, y_tmp = prepare_dataset(df_train, res, astore, dinfo, t2017 + delta)       
    X_l.append(X_tmp)
    y_l.append(y_tmp)
X_train = list(map(lambda x: pd.concat(x), zip(*X_l)))
y_train = np.concatenate(y_l, axis=0)
del X_l, y_l
X_val, y_val = prepare_dataset(df_train,res, astore, dinfo, date(2017, 3, 14))
X_test = prepare_dataset(df_train, res, astore, dinfo, date(2017, 4, 23), is_train=False)

# %%
params = {
    'num_leaves': 31,
    'objective': 'regression',
    'min_data_in_leaf': 300,
    'learning_rate': 0.1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 2,
    'metric': 'l2',
    'num_threads': 12,
}

MAX_ROUNDS = 500
val_pred = []
test_pred = []
cate_vars = ['genre', 'holiday', 'dow']

# %%
for i in range(39):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    dtrain = lgb.Dataset(X_train[i], label=y_train[:, i], categorical_feature=cate_vars)
    dval = lgb.Dataset(X_val[i], label=y_val[:, i], reference=dtrain, categorical_feature=cate_vars)
    bst = lgb.train(params, dtrain, num_boost_round=MAX_ROUNDS, valid_sets=[dtrain, dval],
                    early_stopping_rounds=50, verbose_eval=100)
    print("\n".join(("%s: %.2f" % x) for x in sorted(
        zip(X_train[i].columns, bst.feature_importance("gain")),
        key=lambda x: x[1], reverse=True
    )))
    val_pred.append(bst.predict(
        X_val[i], num_iteration=bst.best_iteration or MAX_ROUNDS))
    test_pred.append(bst.predict(
        X_test[i], num_iteration=bst.best_iteration or MAX_ROUNDS))
# Out:
# ==================================================
# Step 1
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# /home/tselab/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/tselab/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:668: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [100]	training's l2: 0.40278	valid_1's l2: 0.504911
# [200]	training's l2: 0.377091	valid_1's l2: 0.501864
# Early stopping, best iteration is:
# [150]	training's l2: 0.388694	valid_1's l2: 0.501019
# sum_4_dow0_2017: 68169.26
# median_4_dow0_2017: 40849.25
# day_7_2017: 7564.11
# day_14_2017: 4069.19
# res_0_2017: 3965.99
# sum_4_dow6_2017: 2067.83
# median_140_2017: 1863.61
# dow: 1812.98
# day_1_2017: 1454.81
# genre: 1451.82
# day_6_2017: 1134.04
# median_4_dow1_2017: 820.48
# mres_60_2017: 705.40
# median_4_dow6_2017: 676.95
# day_13_2017: 639.60
# median_30_2017: 611.63
# res_0: 584.85
# sum_4_dow1_2017: 525.91
# sum_4_dow5_2017: 510.01
# latitude: 475.86
# day_2_2017: 470.12
# day_5_2017: 455.78
# day_3_2017: 432.53
# longitude: 429.69
# res_7_2017: 389.85
# day_4_2017: 389.11
# mres_30_2017: 384.62
# sum_4_dow3_2017: 379.94
# median_60_2017: 353.72
# res_10_2017: 242.15
# sum_4_dow2_2017: 238.55
# sum_4_dow4_2017: 237.73
# median_4_dow5_2017: 224.60
# median_4_dow2_2017: 222.07
# day_8_2017: 212.46
# res_4_2017: 183.90
# res_14_2017: 181.57
# res_6_2017: 171.91
# res_3_2017: 170.00
# day_11_2017: 164.62
# median_4_dow3_2017: 164.25
# day_12_2017: 149.02
# res_13_2017: 142.45
# median_4_dow4_2017: 133.52
# res_1_2017: 118.27
# day_10_2017: 116.84
# res_2_2017: 115.15
# res_11_2017: 109.95
# res_9_2017: 106.61
# res_5_2017: 105.65
# res_12_2017: 98.95
# holiday: 91.21
# day_9_2017: 89.56
# res_8_2017: 81.34
# res_5: 70.64
# res_3: 53.96
# res_13: 37.74
# mres_140_2017: 28.93
# res_10: 27.50
# res_7: 20.38
# res_4: 18.40
# res_2: 17.66
# res_1: 17.17
# res_14: 16.70
# res_6: 13.29
# res_9: 11.68
# res_11: 10.99
# res_12: 8.95
# res_8: 4.32
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [49]	training's l2: 0.429	valid_1's l2: 0.423381
# median_4_dow1_2017: 55003.59
# sum_4_dow1_2017: 51675.56
# day_6_2017: 6497.86
# day_13_2017: 5718.40
# res_0: 4275.13
# median_140_2017: 2273.81
# dow: 1101.27
# genre: 908.73
# day_5_2017: 786.23
# sum_4_dow6_2017: 728.26
# sum_4_dow2_2017: 673.74
# median_4_dow0_2017: 546.57
# mres_60_2017: 544.77
# sum_4_dow0_2017: 518.66
# median_60_2017: 503.37
# day_1_2017: 404.61
# day_7_2017: 383.92
# day_12_2017: 376.41
# median_4_dow2_2017: 362.61
# day_4_2017: 323.46
# day_3_2017: 318.28
# res_6_2017: 308.03
# day_14_2017: 263.55
# mres_30_2017: 262.62
# median_30_2017: 242.96
# sum_4_dow5_2017: 215.84
# day_2_2017: 185.39
# res_13_2017: 181.37
# median_4_dow3_2017: 180.73
# longitude: 170.23
# res_2_2017: 143.19
# median_4_dow6_2017: 129.64
# latitude: 128.12
# res_12_2017: 117.94
# day_11_2017: 109.59
# res_10_2017: 105.15
# res_11_2017: 83.36
# res_4_2017: 79.67
# res_9_2017: 78.17
# day_10_2017: 69.31
# res_14_2017: 65.01
# day_8_2017: 64.76
# day_9_2017: 59.65
# sum_4_dow3_2017: 55.31
# res_5_2017: 54.47
# res_7: 53.32
# sum_4_dow4_2017: 52.82
# res_5: 52.19
# median_4_dow4_2017: 51.56
# res_3_2017: 40.90
# holiday: 40.13
# res_7_2017: 37.86
# res_14: 34.73
# res_12: 33.59
# median_4_dow5_2017: 31.87
# mres_140_2017: 15.50
# res_10: 10.04
# res_3: 7.88
# res_4: 7.53
# res_0_2017: 7.46
# res_8_2017: 5.46
# res_13: 4.50
# res_1_2017: 3.72
# res_1: 3.20
# res_2: 0.00
# res_6: 0.00
# res_8: 0.00
# res_9: 0.00
# res_11: 0.00
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.407278	valid_1's l2: 0.422226
# Early stopping, best iteration is:
# [95]	training's l2: 0.408816	valid_1's l2: 0.421559
# sum_4_dow2_2017: 73275.38
# median_4_dow2_2017: 40489.34
# res_0: 4319.51
# day_5_2017: 4311.65
# day_12_2017: 2851.43
# median_140_2017: 1338.17
# dow: 1337.17
# genre: 1266.44
# median_4_dow3_2017: 898.10
# sum_4_dow3_2017: 809.67
# median_4_dow1_2017: 780.50
# sum_4_dow1_2017: 770.64
# day_4_2017: 769.56
# day_1_2017: 615.14
# median_60_2017: 614.79
# mres_30_2017: 482.13
# sum_4_dow6_2017: 399.68
# latitude: 379.90
# day_3_2017: 376.05
# mres_60_2017: 366.43
# median_30_2017: 360.69
# day_2_2017: 359.76
# longitude: 351.89
# res_5_2017: 351.87
# day_6_2017: 347.68
# sum_4_dow0_2017: 345.80
# day_13_2017: 319.78
# day_11_2017: 285.52
# res_12_2017: 245.99
# res_1_2017: 238.10
# sum_4_dow5_2017: 216.86
# median_4_dow4_2017: 191.10
# median_4_dow0_2017: 190.24
# sum_4_dow4_2017: 187.43
# res_13_2017: 147.13
# res_8_2017: 142.93
# res_9_2017: 139.97
# day_9_2017: 134.60
# res_3_2017: 132.36
# res_11_2017: 127.26
# day_10_2017: 120.69
# day_7_2017: 114.51
# median_4_dow6_2017: 107.84
# day_14_2017: 105.10
# mres_140_2017: 98.68
# day_8_2017: 92.42
# res_1: 89.40
# res_2_2017: 84.55
# median_4_dow5_2017: 84.53
# res_4_2017: 75.31
# holiday: 64.93
# res_14_2017: 56.05
# res_5: 53.88
# res_10_2017: 50.19
# res_0_2017: 36.33
# res_6_2017: 23.65
# res_14: 18.95
# res_7_2017: 17.88
# res_13: 12.63
# res_9: 10.02
# res_3: 9.38
# res_7: 7.56
# res_2: 7.11
# res_10: 6.95
# res_12: 6.74
# res_11: 6.73
# res_6: 6.45
# res_4: 2.92
# res_8: 0.00
# ==================================================
# Step 4
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.408714	valid_1's l2: 0.409537
# [200]	training's l2: 0.383734	valid_1's l2: 0.408262
# Early stopping, best iteration is:
# [204]	training's l2: 0.382855	valid_1's l2: 0.408007
# sum_4_dow3_2017: 70949.08
# median_4_dow3_2017: 43294.70
# day_4_2017: 4673.70
# res_0: 4389.29
# day_11_2017: 2531.80
# dow: 1873.85
# median_140_2017: 1864.09
# genre: 1854.63
# day_3_2017: 1050.03
# median_60_2017: 1005.15
# median_4_dow2_2017: 888.60
# sum_4_dow4_2017: 827.25
# sum_4_dow2_2017: 786.21
# mres_60_2017: 726.72
# latitude: 697.10
# day_1_2017: 679.36
# longitude: 642.59
# median_4_dow4_2017: 594.88
# sum_4_dow1_2017: 516.11
# sum_4_dow6_2017: 514.09
# median_30_2017: 476.79
# day_2_2017: 461.88
# day_10_2017: 454.60
# day_5_2017: 417.67
# day_12_2017: 395.77
# sum_4_dow5_2017: 389.56
# sum_4_dow0_2017: 377.41
# median_4_dow1_2017: 311.45
# res_4_2017: 287.76
# mres_30_2017: 270.48
# res_10_2017: 222.87
# res_11_2017: 222.71
# median_4_dow5_2017: 220.46
# median_4_dow0_2017: 201.84
# median_4_dow6_2017: 193.01
# day_6_2017: 192.39
# res_14_2017: 191.74
# res_7_2017: 190.87
# res_8_2017: 188.64
# res_0_2017: 185.30
# day_8_2017: 182.09
# res_12_2017: 177.19
# res_2_2017: 170.79
# res_1: 164.86
# day_13_2017: 160.96
# res_7: 159.96
# res_1_2017: 156.25
# day_9_2017: 155.48
# res_2: 155.09
# day_14_2017: 153.32
# res_9_2017: 142.40
# res_3_2017: 126.70
# res_5_2017: 125.58
# day_7_2017: 122.67
# res_13_2017: 109.18
# res_6_2017: 108.34
# holiday: 101.88
# mres_140_2017: 90.10
# res_5: 65.21
# res_13: 49.40
# res_10: 41.88
# res_4: 40.75
# res_9: 27.27
# res_11: 21.89
# res_14: 21.55
# res_12: 20.35
# res_3: 20.14
# res_6: 17.28
# res_8: 8.76
# ==================================================
# Step 5
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.409861	valid_1's l2: 0.401238
# Early stopping, best iteration is:
# [117]	training's l2: 0.405004	valid_1's l2: 0.400063
# median_4_dow4_2017: 52443.06
# sum_4_dow4_2017: 52172.41
# day_3_2017: 11040.39
# day_10_2017: 5652.17
# res_0: 4365.65
# dow: 1572.07
# genre: 1406.43
# median_140_2017: 1359.41
# median_60_2017: 1229.85
# median_4_dow3_2017: 865.89
# sum_4_dow3_2017: 848.74
# sum_4_dow5_2017: 764.87
# day_2_2017: 764.14
# median_4_dow5_2017: 762.40
# mres_60_2017: 694.34
# longitude: 460.48
# day_1_2017: 455.93
# latitude: 433.14
# sum_4_dow2_2017: 384.17
# day_11_2017: 337.78
# sum_4_dow6_2017: 335.62
# median_30_2017: 328.34
# day_9_2017: 303.43
# day_4_2017: 257.59
# sum_4_dow0_2017: 246.44
# mres_30_2017: 245.64
# res_3_2017: 243.26
# median_4_dow6_2017: 235.42
# median_4_dow2_2017: 223.28
# sum_4_dow1_2017: 221.70
# res_10_2017: 188.87
# day_6_2017: 164.77
# res_9_2017: 151.13
# res_11_2017: 150.22
# day_7_2017: 149.75
# res_13_2017: 148.84
# median_4_dow0_2017: 137.94
# res_2_2017: 133.04
# day_5_2017: 132.97
# res_12_2017: 132.27
# day_8_2017: 131.66
# res_6_2017: 130.87
# res_1_2017: 130.20
# res_7_2017: 122.03
# res_3: 119.93
# median_4_dow1_2017: 119.48
# res_8_2017: 111.94
# res_0_2017: 102.95
# day_12_2017: 95.85
# day_13_2017: 93.73
# res_1: 90.37
# day_14_2017: 79.56
# res_7: 77.93
# mres_140_2017: 75.30
# holiday: 74.90
# res_2: 69.94
# res_14_2017: 62.03
# res_5_2017: 60.40
# res_14: 40.82
# res_4_2017: 40.70
# res_13: 25.00
# res_11: 20.20
# res_5: 19.64
# res_6: 12.87
# res_12: 11.17
# res_4: 9.83
# res_9: 7.32
# res_8: 4.51
# res_10: 0.00
# ==================================================
# Step 6
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.411852	valid_1's l2: 0.635092
# Early stopping, best iteration is:
# [122]	training's l2: 0.40515	valid_1's l2: 0.631465
# sum_4_dow5_2017: 59692.99
# median_4_dow5_2017: 56031.46
# res_0: 4430.89
# day_2_2017: 3883.88
# day_9_2017: 2015.47
# dow: 1503.04
# genre: 1451.45
# median_30_2017: 1231.40
# median_140_2017: 1210.75
# sum_4_dow6_2017: 903.02
# sum_4_dow4_2017: 851.16
# day_1_2017: 722.67
# median_4_dow4_2017: 604.37
# median_60_2017: 549.35
# median_4_dow6_2017: 518.09
# longitude: 512.93
# mres_60_2017: 472.93
# latitude: 451.89
# res_2_2017: 422.56
# sum_4_dow3_2017: 413.62
# day_10_2017: 373.69
# day_3_2017: 372.09
# mres_30_2017: 350.01
# day_8_2017: 349.31
# median_4_dow0_2017: 244.11
# sum_4_dow2_2017: 242.95
# sum_4_dow1_2017: 220.89
# day_6_2017: 208.44
# res_9_2017: 198.13
# day_5_2017: 193.48
# day_7_2017: 192.91
# res_10_2017: 187.60
# sum_4_dow0_2017: 183.93
# median_4_dow3_2017: 183.73
# day_12_2017: 179.10
# res_12_2017: 156.96
# res_8_2017: 143.29
# median_4_dow1_2017: 133.07
# res_14_2017: 130.49
# res_6_2017: 126.09
# res_5_2017: 123.13
# day_13_2017: 119.39
# res_0_2017: 114.26
# day_11_2017: 105.40
# res_1_2017: 103.94
# median_4_dow2_2017: 103.50
# mres_140_2017: 102.38
# day_4_2017: 87.44
# res_7_2017: 83.60
# res_2: 83.34
# day_14_2017: 82.72
# res_4: 72.83
# res_11_2017: 72.65
# res_3: 71.20
# holiday: 68.46
# res_13: 63.49
# res_1: 60.47
# res_13_2017: 57.91
# res_11: 57.20
# res_3_2017: 42.64
# res_10: 41.32
# res_4_2017: 40.76
# res_14: 35.82
# res_7: 32.98
# res_6: 22.59
# res_8: 10.63
# res_5: 8.65
# res_9: 6.73
# res_12: 6.55
# ==================================================
# Step 7
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [21]	training's l2: 0.472771	valid_1's l2: 1.55944
# sum_4_dow6_2017: 84877.63
# median_4_dow6_2017: 31874.18
# res_0: 3795.85
# day_1_2017: 3628.92
# day_8_2017: 1477.39
# median_60_2017: 826.26
# median_140_2017: 817.19
# median_4_dow5_2017: 506.65
# dow: 485.55
# sum_4_dow5_2017: 473.03
# median_4_dow0_2017: 440.46
# genre: 427.59
# median_30_2017: 381.54
# mres_30_2017: 334.09
# mres_60_2017: 321.57
# day_7_2017: 304.57
# sum_4_dow0_2017: 291.62
# res_1_2017: 229.25
# sum_4_dow4_2017: 181.22
# day_2_2017: 174.62
# day_14_2017: 147.88
# day_9_2017: 144.73
# res_8_2017: 90.65
# res_5: 77.77
# res_9_2017: 60.97
# day_4_2017: 60.42
# sum_4_dow1_2017: 58.50
# latitude: 53.30
# median_4_dow1_2017: 51.38
# median_4_dow4_2017: 51.30
# res_11_2017: 47.08
# sum_4_dow2_2017: 46.82
# res_6_2017: 46.35
# day_5_2017: 45.47
# day_11_2017: 44.35
# longitude: 42.53
# mres_140_2017: 36.60
# res_3: 34.66
# day_6_2017: 30.97
# res_10: 25.68
# res_14_2017: 25.65
# res_7_2017: 24.06
# median_4_dow3_2017: 21.02
# res_4: 19.74
# res_4_2017: 15.54
# median_4_dow2_2017: 14.75
# res_5_2017: 14.51
# day_10_2017: 13.90
# res_10_2017: 12.59
# res_3_2017: 11.38
# res_2_2017: 8.78
# day_3_2017: 0.00
# day_12_2017: 0.00
# day_13_2017: 0.00
# res_0_2017: 0.00
# res_12_2017: 0.00
# res_13_2017: 0.00
# sum_4_dow3_2017: 0.00
# holiday: 0.00
# res_1: 0.00
# res_2: 0.00
# res_6: 0.00
# res_7: 0.00
# res_8: 0.00
# res_9: 0.00
# res_11: 0.00
# res_12: 0.00
# res_13: 0.00
# res_14: 0.00
# ==================================================
# Step 8
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.436876	valid_1's l2: 0.774059
# [200]	training's l2: 0.405603	valid_1's l2: 0.767419
# Early stopping, best iteration is:
# [216]	training's l2: 0.401496	valid_1's l2: 0.765831
# sum_4_dow0_2017: 74463.06
# median_4_dow0_2017: 29068.01
# day_7_2017: 8890.06
# res_0: 5436.06
# genre: 2739.08
# sum_4_dow6_2017: 2608.76
# dow: 2465.52
# day_14_2017: 2259.87
# median_140_2017: 1986.33
# median_4_dow6_2017: 1528.38
# latitude: 1105.49
# day_6_2017: 973.11
# longitude: 971.25
# holiday: 941.14
# mres_60_2017: 848.58
# day_1_2017: 818.33
# sum_4_dow1_2017: 714.73
# median_30_2017: 663.91
# median_4_dow1_2017: 646.13
# day_13_2017: 627.17
# sum_4_dow5_2017: 582.15
# median_4_dow5_2017: 525.67
# median_60_2017: 500.82
# day_8_2017: 469.34
# day_5_2017: 414.36
# sum_4_dow4_2017: 410.64
# sum_4_dow3_2017: 404.87
# day_3_2017: 390.19
# sum_4_dow2_2017: 385.51
# day_2_2017: 363.88
# res_7_2017: 363.63
# mres_30_2017: 351.27
# mres_140_2017: 270.94
# median_4_dow3_2017: 259.85
# res_3: 259.06
# day_4_2017: 251.18
# median_4_dow2_2017: 249.95
# day_9_2017: 238.02
# day_11_2017: 230.36
# res_4_2017: 216.21
# res_6_2017: 204.27
# median_4_dow4_2017: 199.51
# day_12_2017: 198.23
# res_10_2017: 179.65
# res_3_2017: 176.88
# res_14_2017: 168.05
# res_8_2017: 167.20
# day_10_2017: 167.00
# res_1_2017: 155.95
# res_11_2017: 136.52
# res_9_2017: 133.23
# res_5_2017: 131.80
# res_5: 130.02
# res_13_2017: 122.53
# res_1: 116.16
# res_2: 108.27
# res_12_2017: 106.42
# res_2_2017: 100.40
# res_6: 100.37
# res_0_2017: 98.38
# res_4: 79.43
# res_14: 56.85
# res_13: 49.49
# res_12: 34.97
# res_10: 31.07
# res_7: 16.51
# res_11: 14.37
# res_8: 11.92
# res_9: 10.70
# ==================================================
# Step 9
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.443095	valid_1's l2: 0.429183
# Early stopping, best iteration is:
# [119]	training's l2: 0.435549	valid_1's l2: 0.427047
# sum_4_dow1_2017: 62481.66
# median_4_dow1_2017: 39397.87
# day_6_2017: 7092.15
# res_0: 5691.10
# day_13_2017: 3854.59
# median_140_2017: 2087.28
# genre: 2030.24
# dow: 1855.07
# sum_4_dow0_2017: 1812.18
# median_4_dow0_2017: 1229.57
# day_7_2017: 940.90
# day_5_2017: 798.08
# sum_4_dow2_2017: 715.09
# latitude: 687.41
# longitude: 686.55
# median_4_dow2_2017: 659.07
# mres_60_2017: 651.19
# holiday: 639.59
# sum_4_dow6_2017: 600.48
# day_1_2017: 554.32
# day_12_2017: 407.15
# median_4_dow6_2017: 389.36
# day_14_2017: 347.44
# median_30_2017: 320.15
# day_2_2017: 302.05
# day_3_2017: 292.23
# sum_4_dow3_2017: 284.66
# mres_140_2017: 282.41
# mres_30_2017: 265.13
# median_4_dow3_2017: 248.06
# sum_4_dow5_2017: 246.52
# sum_4_dow4_2017: 243.70
# res_6_2017: 236.66
# median_60_2017: 233.36
# day_4_2017: 225.26
# day_9_2017: 220.46
# res_5_2017: 209.36
# median_4_dow4_2017: 189.47
# res_9_2017: 176.47
# day_10_2017: 159.11
# res_13_2017: 149.62
# res_11_2017: 145.67
# day_11_2017: 134.31
# res_7_2017: 132.16
# res_3_2017: 122.07
# res_14_2017: 120.09
# median_4_dow5_2017: 115.86
# res_4_2017: 115.12
# res_12_2017: 103.71
# res_10_2017: 99.18
# res_8_2017: 97.04
# res_14: 92.07
# res_3: 86.95
# res_2_2017: 82.30
# res_1: 75.96
# day_8_2017: 69.65
# res_6: 58.36
# res_4: 48.06
# res_2: 44.12
# res_5: 43.22
# res_12: 42.21
# res_1_2017: 34.36
# res_7: 33.36
# res_8: 24.49
# res_13: 21.64
# res_10: 14.68
# res_0_2017: 14.64
# res_11: 13.88
# res_9: 10.42
# ==================================================
# Step 10
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.441677	valid_1's l2: 0.458854
# Early stopping, best iteration is:
# [60]	training's l2: 0.461815	valid_1's l2: 0.456996
# sum_4_dow2_2017: 72815.48
# median_4_dow2_2017: 32999.88
# day_5_2017: 6189.88
# res_0: 5412.25
# median_140_2017: 1749.94
# day_12_2017: 1668.51
# median_4_dow1_2017: 1466.05
# genre: 1390.30
# dow: 1334.36
# sum_4_dow1_2017: 1174.47
# day_4_2017: 722.41
# holiday: 650.19
# day_6_2017: 614.47
# sum_4_dow3_2017: 535.37
# mres_60_2017: 492.53
# latitude: 421.20
# longitude: 404.47
# median_30_2017: 404.08
# day_11_2017: 379.46
# mres_30_2017: 377.94
# day_13_2017: 376.85
# median_4_dow0_2017: 373.72
# day_1_2017: 362.61
# median_4_dow3_2017: 357.74
# sum_4_dow0_2017: 286.46
# res_5_2017: 254.40
# sum_4_dow6_2017: 222.63
# median_60_2017: 213.63
# median_4_dow4_2017: 203.44
# res_12_2017: 180.49
# mres_140_2017: 179.45
# day_2_2017: 174.37
# res_4_2017: 147.44
# day_3_2017: 145.00
# sum_4_dow5_2017: 140.25
# res_9_2017: 132.05
# day_8_2017: 131.32
# res_5: 125.75
# sum_4_dow4_2017: 117.05
# day_7_2017: 113.58
# day_9_2017: 101.74
# res_14_2017: 95.34
# res_8_2017: 93.59
# day_14_2017: 83.96
# median_4_dow5_2017: 81.93
# res_3_2017: 75.22
# res_13_2017: 75.11
# day_10_2017: 70.43
# res_7_2017: 59.81
# res_10_2017: 59.65
# median_4_dow6_2017: 57.82
# res_1_2017: 55.08
# res_2_2017: 54.15
# res_6_2017: 46.46
# res_12: 39.29
# res_11_2017: 31.04
# res_14: 27.64
# res_1: 25.95
# res_3: 20.79
# res_2: 17.17
# res_13: 14.41
# res_11: 13.23
# res_10: 13.22
# res_4: 9.63
# res_8: 8.80
# res_6: 8.60
# res_7: 8.01
# res_0_2017: 6.84
# res_9: 2.64
# ==================================================
# Step 11
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.442378	valid_1's l2: 0.430064
# [200]	training's l2: 0.411242	valid_1's l2: 0.427612
# Early stopping, best iteration is:
# [206]	training's l2: 0.409644	valid_1's l2: 0.427084
# sum_4_dow3_2017: 75829.35
# median_4_dow3_2017: 29447.10
# day_4_2017: 7140.57
# res_0: 5600.27
# genre: 2675.46
# dow: 2292.13
# day_11_2017: 2019.38
# median_140_2017: 1841.26
# sum_4_dow2_2017: 1676.90
# median_4_dow2_2017: 1527.65
# latitude: 1303.01
# longitude: 1034.22
# holiday: 1000.35
# day_3_2017: 882.82
# median_60_2017: 804.95
# sum_4_dow4_2017: 774.92
# day_5_2017: 740.24
# median_4_dow4_2017: 681.85
# day_12_2017: 595.44
# day_1_2017: 590.75
# sum_4_dow1_2017: 572.20
# mres_60_2017: 553.84
# sum_4_dow6_2017: 520.98
# day_10_2017: 476.56
# mres_30_2017: 428.82
# sum_4_dow0_2017: 424.55
# day_2_2017: 357.94
# sum_4_dow5_2017: 347.48
# median_4_dow1_2017: 310.96
# median_4_dow6_2017: 293.62
# res_4_2017: 281.76
# mres_140_2017: 281.51
# median_4_dow5_2017: 273.43
# median_30_2017: 253.14
# res_11_2017: 239.13
# res_8_2017: 234.33
# day_6_2017: 232.46
# day_13_2017: 213.63
# median_4_dow0_2017: 196.33
# day_7_2017: 192.84
# day_14_2017: 190.09
# day_9_2017: 186.73
# day_8_2017: 185.70
# res_7_2017: 176.77
# res_6_2017: 175.51
# res_12_2017: 170.87
# res_1_2017: 170.39
# res_14_2017: 170.31
# res_14: 161.79
# res_3_2017: 155.90
# res_9_2017: 146.20
# res_1: 142.64
# res_5: 142.56
# res_5_2017: 122.37
# res_13_2017: 117.11
# res_2: 116.15
# res_10_2017: 110.25
# res_2_2017: 109.84
# res_4: 105.86
# res_8: 97.43
# res_6: 95.94
# res_9: 85.86
# res_7: 83.18
# res_3: 79.14
# res_0_2017: 75.18
# res_13: 67.67
# res_11: 17.78
# res_10: 14.46
# res_12: 9.72
# ==================================================
# Step 12
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.442876	valid_1's l2: 0.478118
# [200]	training's l2: 0.412054	valid_1's l2: 0.475833
# Early stopping, best iteration is:
# [178]	training's l2: 0.417675	valid_1's l2: 0.473515
# sum_4_dow4_2017: 78236.91
# median_4_dow4_2017: 21548.30
# day_3_2017: 13261.12
# res_0: 5434.31
# day_10_2017: 2445.89
# genre: 2379.46
# dow: 2046.68
# sum_4_dow3_2017: 1811.63
# median_4_dow3_2017: 1231.07
# median_140_2017: 1220.09
# latitude: 1058.98
# holiday: 961.67
# longitude: 901.92
# median_60_2017: 883.53
# day_2_2017: 862.40
# median_4_dow5_2017: 828.79
# day_4_2017: 783.65
# median_30_2017: 672.89
# mres_60_2017: 609.31
# sum_4_dow5_2017: 590.25
# sum_4_dow2_2017: 561.72
# day_1_2017: 510.99
# mres_30_2017: 413.88
# day_11_2017: 381.61
# sum_4_dow0_2017: 378.84
# res_3_2017: 352.49
# median_4_dow2_2017: 344.29
# sum_4_dow1_2017: 341.73
# day_9_2017: 334.72
# median_4_dow6_2017: 319.94
# sum_4_dow6_2017: 313.94
# day_7_2017: 275.63
# res_6_2017: 250.17
# day_6_2017: 235.85
# res_2_2017: 229.37
# median_4_dow0_2017: 225.09
# day_8_2017: 207.78
# res_10_2017: 203.30
# day_14_2017: 195.03
# day_12_2017: 194.22
# median_4_dow1_2017: 182.83
# day_13_2017: 171.66
# res_8_2017: 170.04
# res_11_2017: 162.97
# res_7: 153.73
# day_5_2017: 147.79
# res_7_2017: 146.17
# mres_140_2017: 144.84
# res_14: 142.28
# res_14_2017: 137.35
# res_5_2017: 128.56
# res_12_2017: 125.38
# res_13_2017: 118.89
# res_5: 118.10
# res_1: 112.60
# res_4_2017: 110.33
# res_0_2017: 101.09
# res_1_2017: 100.31
# res_4: 97.99
# res_9_2017: 95.27
# res_8: 84.34
# res_2: 78.91
# res_10: 77.02
# res_9: 76.72
# res_3: 65.14
# res_6: 55.58
# res_13: 39.56
# res_11: 21.87
# res_12: 17.11
# ==================================================
# Step 13
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.44492	valid_1's l2: 0.560349
# Early stopping, best iteration is:
# [89]	training's l2: 0.449835	valid_1's l2: 0.55939
# sum_4_dow5_2017: 84586.07
# median_4_dow5_2017: 25191.29
# day_2_2017: 5805.83
# res_0: 5338.64
# genre: 1688.60
# sum_4_dow4_2017: 1674.04
# dow: 1443.24
# median_140_2017: 1265.42
# median_4_dow4_2017: 966.95
# day_1_2017: 954.63
# median_60_2017: 794.06
# day_9_2017: 768.10
# day_3_2017: 756.12
# mres_60_2017: 720.42
# longitude: 624.37
# sum_4_dow6_2017: 616.97
# holiday: 610.94
# latitude: 575.49
# median_30_2017: 498.43
# median_4_dow3_2017: 427.80
# median_4_dow6_2017: 385.18
# res_2_2017: 368.24
# mres_30_2017: 330.85
# sum_4_dow0_2017: 324.70
# day_10_2017: 292.02
# median_4_dow0_2017: 262.92
# sum_4_dow3_2017: 219.49
# sum_4_dow1_2017: 200.87
# sum_4_dow2_2017: 197.05
# day_8_2017: 185.49
# res_5_2017: 169.71
# res_14_2017: 166.14
# day_13_2017: 162.14
# res_1_2017: 154.22
# day_6_2017: 149.77
# res_9_2017: 147.89
# mres_140_2017: 143.55
# res_6_2017: 134.02
# day_14_2017: 132.52
# res_1: 117.01
# day_5_2017: 113.77
# day_4_2017: 113.22
# day_7_2017: 109.51
# day_12_2017: 104.77
# median_4_dow1_2017: 101.10
# day_11_2017: 91.21
# median_4_dow2_2017: 90.12
# res_5: 84.56
# res_10_2017: 73.39
# res_7_2017: 71.06
# res_13_2017: 63.81
# res_12_2017: 53.04
# res_11_2017: 51.20
# res_4_2017: 47.59
# res_4: 46.26
# res_11: 44.18
# res_2: 41.86
# res_7: 40.68
# res_0_2017: 40.54
# res_3: 39.83
# res_10: 38.11
# res_8_2017: 36.06
# res_3_2017: 35.25
# res_12: 32.43
# res_13: 31.13
# res_14: 30.74
# res_9: 29.15
# res_8: 20.56
# res_6: 18.88
# ==================================================
# Step 14
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.448026	valid_1's l2: 0.490448
# Early stopping, best iteration is:
# [77]	training's l2: 0.458608	valid_1's l2: 0.489003
# sum_4_dow6_2017: 96293.79
# median_4_dow6_2017: 16820.07
# res_0: 5342.12
# day_1_2017: 5117.65
# genre: 1508.18
# sum_4_dow5_2017: 1429.31
# dow: 1340.10
# median_4_dow5_2017: 1295.21
# median_140_2017: 1153.11
# holiday: 740.19
# latitude: 610.08
# median_60_2017: 583.78
# day_8_2017: 570.56
# day_2_2017: 548.69
# median_30_2017: 536.91
# sum_4_dow0_2017: 508.63
# day_7_2017: 500.91
# median_4_dow0_2017: 454.09
# longitude: 437.95
# mres_30_2017: 418.97
# mres_60_2017: 388.39
# sum_4_dow1_2017: 335.56
# sum_4_dow4_2017: 324.10
# sum_4_dow2_2017: 283.03
# res_1_2017: 272.75
# mres_140_2017: 229.52
# day_9_2017: 203.20
# day_6_2017: 200.92
# res_5_2017: 198.66
# sum_4_dow3_2017: 183.72
# res_4_2017: 153.97
# median_4_dow4_2017: 147.37
# day_5_2017: 147.12
# res_13_2017: 143.09
# median_4_dow1_2017: 141.75
# day_14_2017: 138.45
# res_8_2017: 130.22
# day_3_2017: 118.94
# day_13_2017: 118.22
# res_9_2017: 112.45
# day_4_2017: 101.87
# day_12_2017: 91.98
# res_5: 91.85
# res_12_2017: 81.08
# res_12: 79.96
# res_10: 79.23
# res_6_2017: 76.45
# res_14: 75.60
# res_3_2017: 74.08
# median_4_dow2_2017: 73.34
# day_10_2017: 71.70
# res_10_2017: 71.60
# res_11_2017: 69.40
# res_1: 68.98
# median_4_dow3_2017: 67.55
# res_11: 60.48
# res_7: 56.39
# res_0_2017: 56.30
# day_11_2017: 44.33
# res_8: 42.20
# res_4: 37.11
# res_2_2017: 36.97
# res_9: 26.27
# res_7_2017: 23.66
# res_2: 15.94
# res_13: 14.66
# res_14_2017: 11.39
# res_6: 11.05
# res_3: 8.35
# ==================================================
# Step 15
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.458317	valid_1's l2: 0.532659
# Early stopping, best iteration is:
# [120]	training's l2: 0.450154	valid_1's l2: 0.532368
# sum_4_dow0_2017: 74869.24
# median_4_dow0_2017: 26270.98
# res_0: 6169.96
# day_7_2017: 5855.20
# day_14_2017: 4009.26
# sum_4_dow6_2017: 2360.76
# genre: 2306.34
# median_140_2017: 1897.18
# dow: 1893.30
# median_4_dow6_2017: 1646.76
# latitude: 1102.45
# day_1_2017: 931.37
# longitude: 919.38
# day_6_2017: 822.00
# holiday: 760.52
# median_4_dow1_2017: 705.51
# mres_60_2017: 639.39
# sum_4_dow1_2017: 619.53
# sum_4_dow5_2017: 562.10
# median_4_dow2_2017: 514.92
# median_60_2017: 461.58
# day_5_2017: 432.82
# day_8_2017: 404.03
# median_30_2017: 373.29
# day_13_2017: 340.19
# sum_4_dow3_2017: 315.43
# mres_30_2017: 296.39
# sum_4_dow2_2017: 292.33
# sum_4_dow4_2017: 272.82
# res_12_2017: 264.96
# day_12_2017: 251.16
# res_7_2017: 247.38
# day_4_2017: 239.95
# day_3_2017: 236.52
# median_4_dow3_2017: 233.17
# res_4_2017: 225.80
# mres_140_2017: 220.73
# median_4_dow5_2017: 203.86
# median_4_dow4_2017: 199.81
# res_14_2017: 199.63
# day_2_2017: 193.88
# day_9_2017: 172.15
# res_3_2017: 171.94
# day_11_2017: 168.80
# res_0_2017: 163.38
# res_2_2017: 129.65
# res_11_2017: 115.15
# res_10_2017: 114.79
# res_13: 111.41
# res_10: 108.15
# res_9_2017: 102.51
# res_8_2017: 100.75
# res_6_2017: 95.07
# res_12: 84.89
# res_3: 77.69
# res_7: 76.39
# res_1: 68.11
# res_2: 59.13
# res_4: 57.73
# res_1_2017: 56.46
# res_9: 56.26
# res_8: 53.66
# res_11: 50.88
# res_5: 50.48
# res_5_2017: 48.84
# res_6: 48.33
# day_10_2017: 47.93
# res_13_2017: 31.05
# res_14: 6.30
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.458144	valid_1's l2: 0.490168
# [200]	training's l2: 0.424897	valid_1's l2: 0.482391
# Early stopping, best iteration is:
# [211]	training's l2: 0.421641	valid_1's l2: 0.480943
# sum_4_dow1_2017: 63399.99
# median_4_dow1_2017: 38292.68
# res_0: 6452.63
# day_13_2017: 5419.17
# day_6_2017: 4171.60
# genre: 3364.74
# median_140_2017: 2626.08
# dow: 2394.53
# sum_4_dow0_2017: 1914.87
# latitude: 1559.27
# median_4_dow0_2017: 1398.43
# longitude: 1253.70
# sum_4_dow2_2017: 955.24
# day_5_2017: 871.81
# day_7_2017: 867.41
# sum_4_dow6_2017: 754.94
# median_4_dow2_2017: 693.40
# mres_60_2017: 683.11
# holiday: 566.23
# day_14_2017: 548.93
# day_1_2017: 467.95
# median_60_2017: 458.54
# median_4_dow3_2017: 454.91
# day_11_2017: 419.36
# sum_4_dow4_2017: 407.10
# sum_4_dow5_2017: 405.92
# sum_4_dow3_2017: 404.47
# median_30_2017: 389.94
# median_4_dow6_2017: 384.16
# median_4_dow5_2017: 383.67
# day_4_2017: 382.22
# day_3_2017: 352.66
# res_6_2017: 345.30
# day_2_2017: 286.24
# res_11_2017: 277.17
# median_4_dow4_2017: 267.00
# res_3_2017: 264.09
# day_12_2017: 263.70
# res_13_2017: 231.35
# res_5: 203.72
# mres_30_2017: 194.03
# res_10_2017: 186.90
# day_10_2017: 182.95
# res_2_2017: 182.46
# mres_140_2017: 182.15
# res_7: 181.31
# res_14_2017: 171.76
# res_1: 151.78
# res_8_2017: 150.52
# day_9_2017: 148.74
# res_12: 144.79
# res_14: 139.92
# res_13: 139.02
# res_11: 130.02
# res_4_2017: 127.90
# res_9_2017: 125.21
# res_12_2017: 120.91
# res_5_2017: 119.74
# res_2: 118.87
# res_1_2017: 118.79
# res_3: 117.86
# day_8_2017: 117.74
# res_0_2017: 114.82
# res_7_2017: 112.44
# res_4: 109.97
# res_6: 91.25
# res_9: 86.80
# res_8: 84.73
# res_10: 80.86
# ==================================================
# Step 17
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.455142	valid_1's l2: 0.478783
# [200]	training's l2: 0.421324	valid_1's l2: 0.473035
# Early stopping, best iteration is:
# [189]	training's l2: 0.424268	valid_1's l2: 0.471634
# sum_4_dow2_2017: 77939.94
# median_4_dow2_2017: 25387.30
# res_0: 6324.46
# day_12_2017: 5303.54
# day_5_2017: 3794.88
# genre: 3076.71
# dow: 2096.41
# median_140_2017: 1992.56
# sum_4_dow1_2017: 1532.78
# latitude: 1479.55
# median_4_dow1_2017: 1234.33
# longitude: 1055.75
# day_6_2017: 882.73
# day_4_2017: 873.85
# day_13_2017: 871.63
# sum_4_dow0_2017: 816.56
# median_60_2017: 771.86
# holiday: 762.34
# sum_4_dow3_2017: 689.23
# mres_60_2017: 683.26
# median_4_dow3_2017: 563.45
# median_4_dow0_2017: 495.24
# sum_4_dow5_2017: 487.53
# day_1_2017: 471.22
# sum_4_dow6_2017: 455.12
# mres_30_2017: 425.89
# sum_4_dow4_2017: 425.00
# median_4_dow4_2017: 411.62
# day_2_2017: 404.17
# day_3_2017: 397.92
# day_10_2017: 328.83
# res_10_2017: 299.25
# median_30_2017: 299.09
# res_5_2017: 281.57
# mres_140_2017: 262.44
# day_11_2017: 223.72
# res_9_2017: 221.78
# median_4_dow5_2017: 218.51
# median_4_dow6_2017: 202.05
# res_12_2017: 197.50
# res_2_2017: 194.30
# res_13_2017: 181.21
# day_14_2017: 176.21
# day_9_2017: 171.74
# res_1: 161.53
# res_4: 157.80
# res_1_2017: 149.22
# day_7_2017: 146.14
# res_11_2017: 144.39
# res_5: 134.99
# res_3_2017: 132.36
# res_11: 129.34
# res_6_2017: 129.03
# res_0_2017: 128.91
# res_13: 124.71
# res_4_2017: 118.09
# res_3: 117.28
# res_7_2017: 113.28
# day_8_2017: 111.56
# res_14: 111.06
# res_12: 107.27
# res_6: 99.33
# res_8: 94.94
# res_7: 94.83
# res_8_2017: 89.19
# res_2: 88.82
# res_9: 88.55
# res_10: 84.07
# res_14_2017: 70.94
# ==================================================
# Step 18
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.456395	valid_1's l2: 0.48426
# [200]	training's l2: 0.423051	valid_1's l2: 0.47756
# [300]	training's l2: 0.399262	valid_1's l2: 0.476143
# [400]	training's l2: 0.379214	valid_1's l2: 0.476112
# Early stopping, best iteration is:
# [379]	training's l2: 0.383305	valid_1's l2: 0.475337
# sum_4_dow3_2017: 87192.98
# median_4_dow3_2017: 19479.50
# res_0: 6631.94
# genre: 3956.92
# day_11_2017: 3343.97
# dow: 2821.51
# day_4_2017: 2633.58
# median_140_2017: 2253.73
# latitude: 2012.36
# longitude: 1767.43
# sum_4_dow2_2017: 1761.06
# median_4_dow2_2017: 1608.86
# median_60_2017: 1108.71
# sum_4_dow1_2017: 1032.79
# sum_4_dow4_2017: 1022.95
# day_3_2017: 852.70
# day_5_2017: 831.11
# holiday: 822.30
# day_12_2017: 819.63
# sum_4_dow6_2017: 816.08
# mres_60_2017: 768.76
# median_4_dow4_2017: 688.22
# day_1_2017: 637.67
# sum_4_dow0_2017: 633.43
# sum_4_dow5_2017: 612.11
# median_4_dow1_2017: 558.74
# median_30_2017: 490.65
# day_10_2017: 474.35
# day_2_2017: 451.89
# median_4_dow5_2017: 443.16
# day_13_2017: 441.62
# day_9_2017: 441.42
# mres_30_2017: 402.15
# median_4_dow0_2017: 371.02
# day_14_2017: 359.17
# median_4_dow6_2017: 337.41
# res_11_2017: 307.72
# res_14: 304.75
# res_4_2017: 295.27
# res_14_2017: 295.07
# day_8_2017: 286.96
# day_6_2017: 275.87
# res_9_2017: 274.93
# res_11: 272.02
# res_0_2017: 270.45
# day_7_2017: 262.35
# res_12_2017: 261.54
# res_1_2017: 259.55
# res_8_2017: 250.58
# res_1: 249.60
# res_2: 242.29
# res_13: 235.39
# mres_140_2017: 233.55
# res_12: 232.59
# res_2_2017: 224.32
# res_5_2017: 223.32
# res_6: 219.33
# res_10_2017: 212.09
# res_4: 210.60
# res_7_2017: 205.32
# res_10: 201.77
# res_9: 199.36
# res_8: 195.64
# res_6_2017: 186.91
# res_3_2017: 183.50
# res_5: 176.19
# res_7: 168.81
# res_3: 158.83
# res_13_2017: 157.80
# ==================================================
# Step 19
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.455153	valid_1's l2: 0.51909
# Early stopping, best iteration is:
# [85]	training's l2: 0.462005	valid_1's l2: 0.518186
# sum_4_dow4_2017: 79684.60
# median_4_dow4_2017: 17005.04
# day_10_2017: 9313.25
# res_0: 6206.04
# day_3_2017: 5142.67
# genre: 2175.20
# median_140_2017: 1896.46
# dow: 1536.18
# median_4_dow3_2017: 1358.73
# sum_4_dow3_2017: 1291.69
# median_60_2017: 1260.99
# latitude: 1080.41
# longitude: 716.92
# mres_60_2017: 715.46
# day_2_2017: 693.94
# holiday: 672.38
# day_4_2017: 646.67
# sum_4_dow5_2017: 604.56
# median_4_dow5_2017: 532.79
# day_11_2017: 518.61
# sum_4_dow2_2017: 376.24
# sum_4_dow0_2017: 338.95
# median_4_dow2_2017: 338.07
# median_4_dow6_2017: 297.05
# day_1_2017: 282.41
# sum_4_dow6_2017: 224.58
# median_4_dow0_2017: 216.93
# res_3_2017: 215.35
# day_14_2017: 200.11
# day_6_2017: 199.24
# mres_30_2017: 187.18
# day_12_2017: 187.00
# res_0_2017: 182.85
# day_13_2017: 179.62
# sum_4_dow1_2017: 174.02
# res_8_2017: 155.42
# day_8_2017: 153.48
# mres_140_2017: 136.98
# res_11_2017: 118.06
# day_9_2017: 115.98
# res_13: 112.83
# median_4_dow1_2017: 106.23
# day_7_2017: 104.45
# median_30_2017: 103.17
# res_13_2017: 95.21
# res_14: 90.82
# day_5_2017: 89.28
# res_2_2017: 86.90
# res_7_2017: 82.15
# res_10_2017: 78.36
# res_12: 72.17
# res_14_2017: 71.67
# res_3: 70.66
# res_4_2017: 68.65
# res_11: 63.34
# res_7: 57.02
# res_9_2017: 55.35
# res_1_2017: 51.52
# res_6_2017: 45.99
# res_5_2017: 44.62
# res_4: 42.86
# res_6: 42.84
# res_1: 42.59
# res_2: 32.71
# res_5: 31.02
# res_12_2017: 28.18
# res_10: 24.62
# res_9: 21.92
# res_8: 14.67
# ==================================================
# Step 20
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.458116	valid_1's l2: 0.628354
# Early stopping, best iteration is:
# [79]	training's l2: 0.469025	valid_1's l2: 0.625663
# sum_4_dow5_2017: 82895.84
# median_4_dow5_2017: 22687.34
# res_0: 6222.31
# day_2_2017: 3060.83
# day_9_2017: 2943.54
# genre: 1888.72
# median_140_2017: 1697.31
# sum_4_dow4_2017: 1249.66
# dow: 1244.13
# median_4_dow4_2017: 1029.81
# median_60_2017: 920.25
# latitude: 917.06
# day_3_2017: 869.03
# sum_4_dow6_2017: 759.65
# mres_60_2017: 711.49
# day_1_2017: 679.84
# day_10_2017: 552.13
# holiday: 538.66
# longitude: 537.50
# median_4_dow6_2017: 520.45
# median_30_2017: 492.65
# sum_4_dow3_2017: 490.67
# median_4_dow3_2017: 442.12
# sum_4_dow0_2017: 394.35
# sum_4_dow1_2017: 346.86
# mres_140_2017: 238.78
# res_2_2017: 228.55
# sum_4_dow2_2017: 225.54
# res_7_2017: 206.22
# median_4_dow0_2017: 184.97
# mres_30_2017: 180.39
# median_4_dow1_2017: 178.21
# day_12_2017: 146.38
# day_7_2017: 146.02
# res_9_2017: 142.72
# day_6_2017: 133.92
# day_13_2017: 129.53
# res_13: 127.21
# res_14: 122.91
# median_4_dow2_2017: 122.00
# day_4_2017: 109.51
# res_10_2017: 104.52
# day_8_2017: 93.42
# day_11_2017: 91.07
# res_8_2017: 86.90
# res_6_2017: 83.96
# res_12_2017: 79.86
# day_5_2017: 79.11
# res_13_2017: 72.93
# res_1_2017: 70.98
# res_4_2017: 69.06
# res_14_2017: 67.17
# res_7: 59.61
# res_11: 53.68
# res_0_2017: 51.01
# day_14_2017: 50.31
# res_4: 46.39
# res_3_2017: 45.60
# res_3: 42.27
# res_1: 39.05
# res_5_2017: 36.31
# res_11_2017: 34.33
# res_10: 26.76
# res_2: 25.61
# res_12: 14.49
# res_9: 14.33
# res_8: 12.64
# res_6: 12.24
# res_5: 4.04
# ==================================================
# Step 21
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.459472	valid_1's l2: 0.557424
# Early stopping, best iteration is:
# [112]	training's l2: 0.453288	valid_1's l2: 0.55553
# sum_4_dow6_2017: 96390.70
# median_4_dow6_2017: 12082.60
# res_0: 6229.40
# day_8_2017: 4037.07
# day_1_2017: 3001.64
# genre: 2368.59
# median_140_2017: 1913.16
# dow: 1564.47
# sum_4_dow5_2017: 1182.07
# latitude: 1070.70
# median_4_dow5_2017: 1030.97
# holiday: 820.63
# median_60_2017: 812.76
# longitude: 740.61
# day_2_2017: 736.36
# sum_4_dow0_2017: 586.85
# day_9_2017: 545.70
# sum_4_dow1_2017: 531.24
# mres_60_2017: 494.58
# sum_4_dow4_2017: 452.70
# median_4_dow0_2017: 451.41
# median_30_2017: 444.41
# day_7_2017: 394.03
# mres_140_2017: 377.37
# day_12_2017: 321.15
# median_4_dow4_2017: 319.27
# day_14_2017: 298.83
# day_6_2017: 248.10
# sum_4_dow3_2017: 245.84
# res_1_2017: 238.56
# day_10_2017: 234.05
# sum_4_dow2_2017: 231.01
# res_6_2017: 210.97
# median_4_dow3_2017: 210.55
# median_4_dow2_2017: 178.13
# mres_30_2017: 177.63
# day_5_2017: 164.13
# median_4_dow1_2017: 163.40
# res_11_2017: 163.19
# res_7: 159.37
# res_8_2017: 144.90
# day_11_2017: 143.94
# res_13: 129.52
# res_9_2017: 127.99
# day_4_2017: 115.00
# res_11: 112.20
# day_3_2017: 108.01
# res_12_2017: 102.87
# res_2: 102.30
# res_7_2017: 99.23
# day_13_2017: 96.54
# res_4_2017: 96.25
# res_2_2017: 94.46
# res_3_2017: 86.25
# res_13_2017: 81.69
# res_1: 79.11
# res_5_2017: 74.69
# res_14: 70.62
# res_3: 63.67
# res_10_2017: 62.39
# res_4: 60.53
# res_14_2017: 54.71
# res_10: 53.17
# res_12: 44.94
# res_8: 40.19
# res_9: 36.30
# res_6: 36.17
# res_0_2017: 22.01
# res_5: 19.65
# ==================================================
# Step 22
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.465269	valid_1's l2: 0.573566
# Early stopping, best iteration is:
# [146]	training's l2: 0.445196	valid_1's l2: 0.568445
# median_4_dow0_2017: 49298.93
# sum_4_dow0_2017: 46742.70
# day_7_2017: 11082.33
# res_0: 6145.43
# genre: 3112.30
# sum_4_dow6_2017: 2328.30
# median_140_2017: 2322.33
# dow: 2185.19
# day_14_2017: 1606.20
# median_60_2017: 1456.42
# latitude: 1435.70
# median_4_dow6_2017: 1111.88
# longitude: 1078.35
# holiday: 996.89
# mres_60_2017: 964.16
# day_1_2017: 910.96
# sum_4_dow1_2017: 797.55
# median_4_dow1_2017: 734.18
# sum_4_dow5_2017: 609.77
# day_6_2017: 552.43
# median_4_dow3_2017: 474.60
# day_8_2017: 447.19
# day_5_2017: 412.05
# day_13_2017: 399.22
# median_4_dow4_2017: 386.93
# sum_4_dow3_2017: 379.94
# median_30_2017: 360.34
# median_4_dow5_2017: 354.29
# sum_4_dow2_2017: 341.37
# median_4_dow2_2017: 325.65
# mres_30_2017: 292.67
# res_14: 285.10
# sum_4_dow4_2017: 249.72
# day_10_2017: 236.04
# day_11_2017: 230.67
# day_4_2017: 220.76
# day_2_2017: 220.61
# mres_140_2017: 219.60
# day_12_2017: 218.54
# res_11_2017: 210.54
# res_7_2017: 201.16
# res_5_2017: 184.43
# res_6_2017: 178.95
# res_1_2017: 160.81
# day_3_2017: 155.87
# day_9_2017: 154.58
# res_2_2017: 148.85
# res_1: 136.96
# res_3_2017: 134.36
# res_4_2017: 128.61
# res_14_2017: 128.18
# res_2: 124.32
# res_10_2017: 123.46
# res_8_2017: 122.16
# res_13: 120.82
# res_3: 111.49
# res_13_2017: 102.26
# res_7: 90.59
# res_11: 83.75
# res_9: 82.51
# res_10: 74.48
# res_12_2017: 74.27
# res_4: 65.46
# res_6: 55.45
# res_0_2017: 55.00
# res_12: 47.89
# res_8: 40.05
# res_5: 31.67
# res_9_2017: 21.47
# ==================================================
# Step 23
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.466449	valid_1's l2: 0.481603
# Early stopping, best iteration is:
# [80]	training's l2: 0.477088	valid_1's l2: 0.480552
# sum_4_dow1_2017: 55821.69
# median_4_dow1_2017: 39187.52
# day_6_2017: 8821.05
# res_0: 6547.99
# median_140_2017: 3171.48
# day_13_2017: 3081.00
# genre: 2446.70
# dow: 1541.15
# sum_4_dow0_2017: 1110.77
# day_7_2017: 1036.52
# latitude: 1027.94
# median_4_dow0_2017: 1009.45
# mres_60_2017: 737.94
# median_60_2017: 722.51
# longitude: 707.46
# median_4_dow2_2017: 632.08
# sum_4_dow2_2017: 604.92
# median_30_2017: 483.79
# sum_4_dow6_2017: 454.93
# day_12_2017: 431.19
# median_4_dow3_2017: 412.11
# day_5_2017: 399.02
# holiday: 394.89
# median_4_dow6_2017: 355.35
# mres_140_2017: 337.55
# day_14_2017: 291.00
# median_4_dow5_2017: 271.69
# sum_4_dow3_2017: 260.39
# day_1_2017: 257.45
# day_4_2017: 248.29
# res_6_2017: 232.94
# mres_30_2017: 232.93
# res_4_2017: 228.21
# day_3_2017: 226.21
# res_7: 215.17
# day_10_2017: 210.59
# res_13_2017: 206.37
# sum_4_dow4_2017: 194.04
# day_2_2017: 175.95
# day_11_2017: 175.65
# sum_4_dow5_2017: 173.82
# res_7_2017: 143.48
# res_13: 129.37
# res_10_2017: 120.04
# median_4_dow4_2017: 112.48
# res_9_2017: 102.75
# day_9_2017: 97.52
# res_14: 94.17
# res_3_2017: 91.07
# res_5_2017: 90.82
# day_8_2017: 90.79
# res_14_2017: 89.43
# res_3: 85.18
# res_12_2017: 62.66
# res_11: 56.72
# res_2_2017: 52.41
# res_11_2017: 46.01
# res_1: 44.82
# res_1_2017: 39.13
# res_2: 29.63
# res_5: 24.21
# res_9: 18.34
# res_4: 15.62
# res_0_2017: 15.07
# res_12: 13.57
# res_10: 11.67
# res_8: 10.75
# res_6: 10.08
# res_8_2017: 0.00
# ==================================================
# Step 24
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.464317	valid_1's l2: 0.509564
# Early stopping, best iteration is:
# [131]	training's l2: 0.45074	valid_1's l2: 0.507619
# sum_4_dow2_2017: 54383.11
# median_4_dow2_2017: 46792.40
# res_0: 6683.43
# day_5_2017: 6041.07
# genre: 2964.79
# median_140_2017: 2354.39
# dow: 1860.55
# day_12_2017: 1752.68
# latitude: 1555.82
# sum_4_dow1_2017: 1451.20
# median_4_dow1_2017: 1008.24
# longitude: 986.90
# day_6_2017: 903.26
# median_60_2017: 891.76
# holiday: 856.84
# sum_4_dow0_2017: 832.16
# mres_60_2017: 815.21
# sum_4_dow3_2017: 807.90
# median_4_dow0_2017: 653.94
# day_4_2017: 556.28
# mres_140_2017: 536.72
# median_4_dow3_2017: 530.91
# day_13_2017: 499.53
# day_11_2017: 338.57
# median_4_dow5_2017: 336.81
# day_2_2017: 332.63
# day_3_2017: 330.16
# sum_4_dow6_2017: 306.99
# sum_4_dow4_2017: 305.64
# median_4_dow4_2017: 295.87
# day_1_2017: 294.07
# median_4_dow6_2017: 282.29
# median_30_2017: 273.20
# sum_4_dow5_2017: 257.87
# day_14_2017: 224.56
# res_7: 216.83
# res_5_2017: 209.03
# mres_30_2017: 183.31
# res_9_2017: 173.81
# res_2_2017: 166.21
# res_14: 153.48
# day_8_2017: 153.29
# res_6_2017: 150.11
# res_14_2017: 145.54
# res_10_2017: 145.36
# res_8_2017: 143.40
# res_13_2017: 139.10
# res_13: 137.55
# day_9_2017: 132.19
# res_3_2017: 129.25
# day_7_2017: 127.50
# res_1: 124.41
# res_2: 117.34
# res_11: 109.24
# res_4_2017: 107.33
# day_10_2017: 94.72
# res_11_2017: 93.97
# res_0_2017: 92.75
# res_12_2017: 91.24
# res_5: 78.29
# res_3: 73.71
# res_6: 59.21
# res_1_2017: 58.15
# res_12: 56.03
# res_10: 54.21
# res_8: 51.01
# res_4: 49.73
# res_9: 43.69
# res_7_2017: 38.42
# ==================================================
# Step 25
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.465479	valid_1's l2: 0.492408
# Early stopping, best iteration is:
# [117]	training's l2: 0.457053	valid_1's l2: 0.490997
# sum_4_dow3_2017: 73453.04
# median_4_dow3_2017: 26544.46
# res_0: 6631.90
# day_4_2017: 6621.42
# genre: 2866.56
# median_140_2017: 2253.73
# day_11_2017: 1886.57
# dow: 1728.71
# latitude: 1417.62
# sum_4_dow2_2017: 1394.35
# median_60_2017: 1184.03
# median_4_dow2_2017: 1067.97
# day_5_2017: 933.42
# median_4_dow1_2017: 805.89
# holiday: 773.39
# mres_60_2017: 753.23
# longitude: 752.99
# sum_4_dow4_2017: 691.73
# sum_4_dow0_2017: 615.62
# day_3_2017: 584.32
# median_4_dow4_2017: 544.78
# sum_4_dow1_2017: 509.97
# median_4_dow0_2017: 472.78
# day_10_2017: 438.84
# day_12_2017: 433.97
# mres_140_2017: 378.47
# day_2_2017: 327.75
# sum_4_dow6_2017: 300.87
# day_1_2017: 300.78
# sum_4_dow5_2017: 299.56
# day_7_2017: 241.46
# res_11_2017: 226.90
# median_4_dow6_2017: 186.68
# day_6_2017: 175.76
# res_13_2017: 174.55
# res_11: 172.65
# res_4_2017: 172.01
# median_30_2017: 167.92
# res_12_2017: 167.70
# mres_30_2017: 159.77
# day_14_2017: 155.82
# res_7_2017: 153.61
# median_4_dow5_2017: 153.33
# day_13_2017: 150.91
# res_2_2017: 149.48
# day_9_2017: 148.62
# day_8_2017: 147.86
# res_1_2017: 142.03
# res_13: 132.05
# res_0_2017: 120.04
# res_5_2017: 111.90
# res_10_2017: 95.10
# res_1: 82.51
# res_8_2017: 79.04
# res_3_2017: 76.69
# res_7: 65.63
# res_3: 64.35
# res_14_2017: 62.10
# res_6_2017: 59.65
# res_9_2017: 55.34
# res_2: 51.38
# res_4: 50.79
# res_12: 46.72
# res_8: 41.41
# res_9: 40.72
# res_6: 38.59
# res_10: 36.67
# res_14: 34.86
# res_5: 29.29
# ==================================================
# Step 26
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.464805	valid_1's l2: 0.413368
# [200]	training's l2: 0.429253	valid_1's l2: 0.411859
# Early stopping, best iteration is:
# [170]	training's l2: 0.438058	valid_1's l2: 0.409994
# sum_4_dow4_2017: 60317.77
# median_4_dow4_2017: 32321.55
# day_3_2017: 14309.66
# res_0: 6674.28
# genre: 3271.06
# day_10_2017: 2376.87
# dow: 2201.72
# median_140_2017: 1960.48
# latitude: 1784.58
# sum_4_dow3_2017: 1617.98
# median_60_2017: 1103.08
# longitude: 1059.13
# median_4_dow3_2017: 967.80
# day_4_2017: 928.68
# holiday: 927.85
# mres_60_2017: 893.67
# sum_4_dow5_2017: 803.76
# median_4_dow0_2017: 690.44
# median_4_dow5_2017: 655.30
# median_4_dow2_2017: 612.57
# sum_4_dow2_2017: 571.73
# sum_4_dow1_2017: 495.54
# day_2_2017: 474.05
# sum_4_dow6_2017: 465.61
# day_11_2017: 465.54
# day_1_2017: 413.35
# mres_140_2017: 406.44
# sum_4_dow0_2017: 405.76
# day_12_2017: 376.59
# day_9_2017: 352.37
# day_7_2017: 343.40
# median_4_dow1_2017: 329.56
# day_6_2017: 304.44
# median_30_2017: 281.01
# res_12_2017: 247.74
# res_3_2017: 235.85
# day_13_2017: 220.48
# res_13: 203.18
# res_14_2017: 197.68
# day_5_2017: 196.88
# res_1_2017: 184.73
# median_4_dow6_2017: 172.41
# res_11_2017: 169.91
# res_9_2017: 161.19
# mres_30_2017: 151.55
# res_1: 150.13
# res_10_2017: 144.80
# res_6_2017: 132.77
# res_13_2017: 129.48
# res_8_2017: 129.40
# res_7_2017: 118.90
# day_8_2017: 117.76
# res_4_2017: 114.59
# res_14: 109.40
# day_14_2017: 106.37
# res_11: 105.17
# res_2: 100.86
# res_3: 99.64
# res_2_2017: 95.67
# res_5_2017: 94.50
# res_6: 92.09
# res_4: 89.64
# res_7: 87.00
# res_0_2017: 85.16
# res_10: 76.78
# res_9: 75.93
# res_12: 64.31
# res_8: 58.59
# res_5: 53.83
# ==================================================
# Step 27
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.467771	valid_1's l2: 0.571371
# [200]	training's l2: 0.430967	valid_1's l2: 0.568686
# Early stopping, best iteration is:
# [161]	training's l2: 0.442732	valid_1's l2: 0.567018
# sum_4_dow5_2017: 53611.46
# median_4_dow5_2017: 49514.10
# res_0: 6407.61
# day_2_2017: 5767.78
# genre: 3329.97
# median_140_2017: 1930.25
# dow: 1914.25
# latitude: 1546.80
# sum_4_dow4_2017: 1244.29
# day_3_2017: 1164.66
# median_4_dow4_2017: 1093.41
# day_9_2017: 1031.25
# sum_4_dow6_2017: 990.13
# longitude: 960.13
# holiday: 925.27
# mres_60_2017: 891.98
# median_4_dow1_2017: 815.91
# median_60_2017: 728.75
# sum_4_dow3_2017: 688.21
# sum_4_dow2_2017: 554.16
# median_4_dow3_2017: 529.16
# sum_4_dow0_2017: 514.60
# day_10_2017: 495.06
# day_1_2017: 475.68
# median_4_dow6_2017: 474.56
# median_4_dow2_2017: 412.32
# mres_140_2017: 399.57
# day_5_2017: 354.06
# day_8_2017: 327.52
# sum_4_dow1_2017: 316.37
# median_4_dow0_2017: 293.23
# res_2_2017: 282.73
# day_6_2017: 259.61
# res_11_2017: 219.81
# day_11_2017: 212.87
# res_7: 204.31
# res_14: 203.62
# res_13: 181.62
# day_14_2017: 181.10
# res_10_2017: 180.66
# median_30_2017: 179.68
# res_6_2017: 179.51
# res_13_2017: 173.01
# day_7_2017: 166.04
# day_4_2017: 161.88
# mres_30_2017: 156.89
# res_12_2017: 143.10
# res_1: 142.36
# day_13_2017: 141.85
# res_14_2017: 141.05
# res_9_2017: 136.21
# res_5_2017: 126.57
# res_7_2017: 126.32
# res_0_2017: 124.49
# res_3: 123.18
# res_1_2017: 120.93
# res_3_2017: 113.75
# res_11: 107.73
# res_10: 105.16
# res_2: 91.47
# res_4: 88.84
# res_8_2017: 88.25
# res_4_2017: 82.00
# res_9: 80.42
# day_12_2017: 78.35
# res_12: 59.00
# res_8: 56.13
# res_6: 50.46
# res_5: 42.82
# ==================================================
# Step 28
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.468274	valid_1's l2: 0.486635
# [200]	training's l2: 0.432889	valid_1's l2: 0.476659
# Early stopping, best iteration is:
# [246]	training's l2: 0.420478	valid_1's l2: 0.472898
# sum_4_dow6_2017: 83778.34
# median_4_dow6_2017: 22270.56
# res_0: 6774.73
# day_1_2017: 5753.52
# genre: 3754.06
# median_140_2017: 2235.70
# dow: 2026.80
# latitude: 1832.13
# sum_4_dow5_2017: 1634.46
# longitude: 1342.99
# day_2_2017: 1178.66
# median_4_dow5_2017: 1062.41
# median_4_dow2_2017: 948.82
# holiday: 912.87
# median_4_dow0_2017: 855.90
# sum_4_dow4_2017: 823.07
# day_8_2017: 821.32
# sum_4_dow0_2017: 804.38
# median_60_2017: 725.40
# mres_60_2017: 721.70
# sum_4_dow3_2017: 698.43
# day_7_2017: 606.58
# median_4_dow4_2017: 591.19
# sum_4_dow1_2017: 584.52
# sum_4_dow2_2017: 578.59
# mres_140_2017: 570.54
# day_9_2017: 551.60
# median_30_2017: 478.68
# res_1_2017: 372.15
# day_10_2017: 304.00
# day_14_2017: 295.21
# mres_30_2017: 294.76
# median_4_dow1_2017: 281.16
# day_4_2017: 280.29
# res_10_2017: 276.73
# day_3_2017: 261.89
# day_5_2017: 260.48
# day_6_2017: 251.49
# res_1: 247.60
# res_7: 245.79
# median_4_dow3_2017: 238.06
# res_2_2017: 235.60
# res_13: 218.88
# res_12_2017: 213.69
# res_5_2017: 208.20
# day_13_2017: 200.68
# res_4_2017: 200.49
# res_10: 194.46
# day_12_2017: 192.26
# day_11_2017: 190.65
# res_3: 177.55
# res_9_2017: 172.06
# res_14_2017: 168.45
# res_11_2017: 167.33
# res_13_2017: 165.65
# res_14: 164.69
# res_8_2017: 160.90
# res_11: 159.51
# res_7_2017: 153.72
# res_0_2017: 153.65
# res_2: 151.82
# res_3_2017: 145.19
# res_6: 143.27
# res_6_2017: 138.80
# res_4: 137.55
# res_9: 126.91
# res_12: 114.41
# res_5: 112.65
# res_8: 107.90
# ==================================================
# Step 29
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.479376	valid_1's l2: 0.508992
# Early stopping, best iteration is:
# [98]	training's l2: 0.480266	valid_1's l2: 0.508137
# median_4_dow0_2017: 57309.52
# sum_4_dow0_2017: 36952.09
# day_7_2017: 7477.28
# res_0: 6990.89
# genre: 3000.65
# median_140_2017: 2596.34
# sum_4_dow6_2017: 1801.19
# dow: 1777.83
# day_14_2017: 1776.08
# latitude: 1322.41
# day_6_2017: 1104.26
# day_1_2017: 1059.32
# median_4_dow5_2017: 883.10
# median_4_dow6_2017: 861.81
# median_60_2017: 857.15
# mres_60_2017: 809.93
# holiday: 745.51
# longitude: 727.98
# sum_4_dow5_2017: 695.18
# median_4_dow1_2017: 676.74
# mres_140_2017: 572.02
# sum_4_dow1_2017: 558.36
# median_30_2017: 473.28
# res_14: 459.84
# median_4_dow2_2017: 435.44
# ...
# sum_4_dow6_2017: 482.34
# holiday: 418.02
# mres_140_2017: 409.88
# day_12_2017: 333.51
# median_4_dow4_2017: 332.23
# day_2_2017: 280.75
# res_6_2017: 267.09
# sum_4_dow5_2017: 264.72
# day_1_2017: 258.41
# median_4_dow3_2017: 242.23
# sum_4_dow4_2017: 222.42
# day_14_2017: 209.56
# day_9_2017: 182.55
# sum_4_dow3_2017: 167.15
# res_8_2017: 156.10
# day_4_2017: 149.96
# res_11: 148.12
# median_4_dow5_2017: 142.19
# res_2_2017: 134.01
# day_3_2017: 130.30
# res_13: 125.94
# res_10_2017: 124.94
# res_11_2017: 123.72
# res_5_2017: 105.57
# day_10_2017: 102.53
# res_13_2017: 96.83
# day_8_2017: 95.93
# res_7_2017: 95.89
# day_11_2017: 95.51
# res_14_2017: 95.42
# res_9_2017: 90.79
# mres_30_2017: 74.23
# res_4_2017: 74.03
# res_12_2017: 70.76
# res_3_2017: 69.46
# res_10: 57.17
# res_2: 52.59
# res_3: 46.00
# res_1: 43.96
# res_0_2017: 40.14
# res_12: 24.41
# res_1_2017: 22.01
# res_8: 21.75
# res_7: 19.57
# res_4: 18.18
# res_9: 17.71
# res_6: 12.84
# res_5: 0.00
# ==================================================
# Step 31
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.473903	valid_1's l2: 0.453379
# Early stopping, best iteration is:
# [130]	training's l2: 0.460247	valid_1's l2: 0.450711
# sum_4_dow2_2017: 53653.61
# median_4_dow2_2017: 43360.24
# res_0: 7801.01
# day_5_2017: 4659.07
# genre: 3187.40
# median_140_2017: 3107.52
# latitude: 1944.37
# dow: 1912.46
# day_12_2017: 1727.42
# sum_4_dow1_2017: 1296.19
# median_4_dow1_2017: 1260.33
# median_4_dow0_2017: 1221.25
# mres_60_2017: 940.39
# day_4_2017: 925.31
# day_6_2017: 871.17
# longitude: 870.82
# sum_4_dow0_2017: 822.36
# median_60_2017: 797.38
# holiday: 788.27
# median_4_dow3_2017: 786.04
# sum_4_dow3_2017: 662.10
# mres_140_2017: 481.21
# res_14: 454.77
# sum_4_dow4_2017: 411.66
# day_11_2017: 411.58
# median_4_dow5_2017: 376.09
# day_13_2017: 367.38
# day_14_2017: 302.20
# day_1_2017: 300.93
# sum_4_dow6_2017: 299.45
# median_4_dow4_2017: 283.27
# res_14_2017: 267.01
# sum_4_dow5_2017: 262.86
# median_30_2017: 245.42
# day_7_2017: 243.49
# res_13: 232.66
# day_3_2017: 222.94
# res_5_2017: 216.26
# res_7_2017: 213.07
# res_1_2017: 207.49
# median_4_dow6_2017: 187.75
# res_13_2017: 185.71
# res_7: 184.55
# res_11: 183.45
# day_9_2017: 172.03
# mres_30_2017: 149.31
# day_8_2017: 148.09
# day_2_2017: 147.18
# res_12_2017: 136.83
# day_10_2017: 136.80
# res_9_2017: 125.96
# res_10_2017: 114.93
# res_8_2017: 114.50
# res_3: 104.12
# res_1: 102.70
# res_0_2017: 100.98
# res_6_2017: 97.30
# res_2_2017: 89.23
# res_4_2017: 85.19
# res_2: 79.70
# res_4: 75.41
# res_11_2017: 67.56
# res_9: 63.26
# res_3_2017: 59.90
# res_10: 56.37
# res_5: 46.34
# res_6: 42.31
# res_8: 35.38
# res_12: 35.08
# ==================================================
# Step 32
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.473439	valid_1's l2: 0.415337
# Early stopping, best iteration is:
# [123]	training's l2: 0.463555	valid_1's l2: 0.412898
# sum_4_dow3_2017: 58659.02
# median_4_dow3_2017: 40499.74
# res_0: 7314.80
# day_4_2017: 3851.92
# genre: 3031.63
# median_140_2017: 2528.68
# dow: 1903.67
# latitude: 1555.37
# sum_4_dow2_2017: 1342.01
# longitude: 1135.40
# median_4_dow2_2017: 1118.91
# median_60_2017: 1113.11
# sum_4_dow1_2017: 1063.30
# day_3_2017: 951.67
# day_11_2017: 869.93
# day_5_2017: 787.75
# mres_60_2017: 779.73
# holiday: 762.28
# mres_140_2017: 762.09
# median_4_dow4_2017: 698.34
# sum_4_dow4_2017: 568.91
# res_14: 563.20
# day_13_2017: 506.31
# median_4_dow1_2017: 482.85
# median_4_dow0_2017: 420.38
# sum_4_dow5_2017: 391.81
# sum_4_dow0_2017: 386.09
# median_4_dow6_2017: 371.14
# day_10_2017: 340.41
# sum_4_dow6_2017: 335.51
# day_12_2017: 279.07
# res_14_2017: 250.48
# day_1_2017: 232.47
# res_13_2017: 227.32
# median_4_dow5_2017: 223.21
# day_2_2017: 209.31
# median_30_2017: 201.89
# day_6_2017: 194.47
# day_14_2017: 193.06
# res_7: 188.91
# res_1: 184.34
# res_13: 174.25
# res_0_2017: 161.42
# res_6_2017: 157.99
# day_9_2017: 155.04
# day_7_2017: 153.70
# res_4_2017: 146.17
# res_11_2017: 138.84
# mres_30_2017: 137.04
# res_12_2017: 129.88
# res_1_2017: 126.11
# res_8_2017: 115.51
# res_7_2017: 115.39
# res_10_2017: 109.03
# day_8_2017: 107.94
# res_3_2017: 104.22
# res_11: 103.74
# res_5_2017: 97.40
# res_2: 94.14
# res_9_2017: 87.80
# res_5: 87.17
# res_3: 71.46
# res_2_2017: 67.11
# res_4: 58.66
# res_10: 58.42
# res_6: 48.18
# res_12: 41.38
# res_9: 40.92
# res_8: 34.18
# ==================================================
# Step 33
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.471517	valid_1's l2: 0.48872
# Early stopping, best iteration is:
# [141]	training's l2: 0.454313	valid_1's l2: 0.485765
# sum_4_dow4_2017: 52589.13
# median_4_dow4_2017: 38147.01
# day_3_2017: 9692.83
# res_0: 7831.04
# day_10_2017: 3613.21
# genre: 3447.92
# median_140_2017: 2514.70
# dow: 1999.73
# sum_4_dow3_2017: 1863.56
# latitude: 1726.78
# median_60_2017: 1107.39
# median_4_dow5_2017: 1093.16
# longitude: 1059.13
# median_4_dow3_2017: 1047.11
# sum_4_dow2_2017: 1009.70
# mres_60_2017: 935.50
# sum_4_dow5_2017: 809.14
# day_2_2017: 778.83
# holiday: 759.57
# median_4_dow0_2017: 665.64
# day_4_2017: 595.84
# median_4_dow2_2017: 523.85
# sum_4_dow6_2017: 514.33
# mres_140_2017: 510.21
# median_4_dow1_2017: 409.78
# res_14: 402.78
# sum_4_dow1_2017: 389.61
# sum_4_dow0_2017: 382.72
# day_9_2017: 335.90
# median_30_2017: 297.20
# day_11_2017: 295.01
# day_12_2017: 285.28
# median_4_dow6_2017: 272.49
# res_12_2017: 261.80
# day_5_2017: 254.82
# res_13: 237.47
# day_1_2017: 232.04
# res_5_2017: 191.84
# res_13_2017: 183.57
# res_14_2017: 177.92
# res_7: 175.79
# day_8_2017: 163.67
# res_7_2017: 158.23
# res_2_2017: 157.75
# mres_30_2017: 152.01
# day_6_2017: 134.27
# day_13_2017: 132.83
# res_3_2017: 132.76
# res_10_2017: 132.63
# day_7_2017: 132.02
# res_11_2017: 128.87
# res_1: 125.25
# day_14_2017: 120.26
# res_11: 115.26
# res_9_2017: 114.69
# res_4: 108.36
# res_6_2017: 100.18
# res_4_2017: 92.04
# res_8_2017: 91.26
# res_12: 88.77
# res_0_2017: 85.79
# res_2: 78.70
# res_9: 72.06
# res_1_2017: 70.09
# res_3: 57.46
# res_6: 50.12
# res_8: 46.78
# res_5: 45.14
# res_10: 41.29
# ==================================================
# Step 34
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.472117	valid_1's l2: 0.503986
# [200]	training's l2: 0.435487	valid_1's l2: 0.503129
# Early stopping, best iteration is:
# [213]	training's l2: 0.431889	valid_1's l2: 0.501148
# sum_4_dow5_2017: 60582.96
# median_4_dow5_2017: 39370.57
# res_0: 7663.16
# genre: 4054.60
# day_2_2017: 3921.86
# median_140_2017: 2433.65
# dow: 2404.20
# latitude: 2156.76
# sum_4_dow4_2017: 1611.83
# longitude: 1378.60
# median_4_dow3_2017: 1374.74
# median_60_2017: 1062.62
# median_4_dow4_2017: 1058.55
# mres_60_2017: 987.20
# holiday: 978.73
# day_3_2017: 975.62
# sum_4_dow6_2017: 965.90
# day_9_2017: 960.76
# sum_4_dow3_2017: 882.70
# day_1_2017: 848.81
# median_4_dow6_2017: 821.11
# median_4_dow1_2017: 764.94
# sum_4_dow0_2017: 706.22
# mres_140_2017: 577.90
# sum_4_dow2_2017: 526.78
# sum_4_dow1_2017: 440.87
# median_4_dow2_2017: 402.38
# res_14: 387.29
# day_10_2017: 385.40
# res_11_2017: 354.98
# day_8_2017: 353.09
# day_4_2017: 303.60
# res_2_2017: 278.04
# median_4_dow0_2017: 250.35
# res_12_2017: 233.45
# res_13: 231.59
# day_14_2017: 208.96
# res_7: 204.57
# res_1: 201.18
# day_7_2017: 198.92
# day_13_2017: 196.53
# res_6_2017: 187.76
# day_6_2017: 183.05
# res_14_2017: 173.58
# res_3_2017: 172.37
# res_9: 170.26
# res_5_2017: 169.56
# median_30_2017: 168.12
# day_5_2017: 167.05
# res_4_2017: 166.41
# res_3: 164.49
# res_13_2017: 163.22
# day_11_2017: 161.53
# res_9_2017: 157.59
# res_8_2017: 156.02
# res_10_2017: 155.98
# res_12: 154.12
# res_2: 150.18
# res_11: 147.71
# res_1_2017: 145.15
# mres_30_2017: 144.20
# res_4: 136.98
# day_12_2017: 123.09
# res_0_2017: 110.28
# res_8: 97.22
# res_7_2017: 95.18
# res_10: 90.04
# res_5: 82.92
# res_6: 63.27
# ==================================================
# Step 35
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.47236	valid_1's l2: 0.520626
# Early stopping, best iteration is:
# [120]	training's l2: 0.462642	valid_1's l2: 0.51709
# sum_4_dow6_2017: 80178.79
# median_4_dow6_2017: 24264.84
# res_0: 7634.87
# genre: 3255.81
# day_1_2017: 2828.27
# median_140_2017: 2131.83
# dow: 1752.87
# median_60_2017: 1688.29
# sum_4_dow5_2017: 1599.59
# latitude: 1483.64
# median_4_dow4_2017: 1284.75
# longitude: 1000.79
# median_4_dow5_2017: 954.37
# day_2_2017: 776.96
# median_4_dow0_2017: 774.52
# mres_60_2017: 760.75
# mres_140_2017: 681.80
# holiday: 673.80
# sum_4_dow0_2017: 631.07
# median_4_dow2_2017: 590.65
# day_8_2017: 524.73
# sum_4_dow4_2017: 467.96
# day_7_2017: 444.00
# median_4_dow3_2017: 429.08
# sum_4_dow3_2017: 415.19
# sum_4_dow1_2017: 402.90
# res_14: 355.56
# day_3_2017: 313.89
# day_14_2017: 256.50
# day_13_2017: 245.30
# res_1_2017: 235.16
# median_30_2017: 217.68
# sum_4_dow2_2017: 210.26
# day_6_2017: 198.90
# day_9_2017: 175.50
# res_13: 174.13
# mres_30_2017: 171.56
# day_10_2017: 165.41
# res_8_2017: 164.76
# res_5_2017: 160.86
# res_11_2017: 160.07
# res_3_2017: 156.71
# median_4_dow1_2017: 155.53
# res_1: 149.02
# res_10_2017: 146.75
# day_4_2017: 138.86
# res_9_2017: 126.25
# res_6_2017: 125.66
# day_11_2017: 125.15
# res_9: 122.69
# day_5_2017: 105.14
# res_2_2017: 101.66
# res_14_2017: 101.47
# res_12_2017: 100.73
# res_3: 93.73
# res_2: 93.59
# day_12_2017: 84.25
# res_4_2017: 80.49
# res_13_2017: 76.98
# res_4: 68.09
# res_12: 67.57
# res_7_2017: 67.25
# res_10: 60.88
# res_11: 58.19
# res_0_2017: 51.35
# res_5: 40.31
# res_6: 39.31
# res_8: 31.73
# res_7: 30.09
# ==================================================
# Step 36
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.47655	valid_1's l2: 0.500632
# Early stopping, best iteration is:
# [143]	training's l2: 0.457707	valid_1's l2: 0.499202
# sum_4_dow0_2017: 67680.63
# median_4_dow0_2017: 26285.21
# res_0: 8115.48
# day_7_2017: 5518.15
# genre: 3740.18
# median_140_2017: 2850.29
# day_14_2017: 2450.23
# dow: 2266.10
# sum_4_dow6_2017: 2169.30
# latitude: 1991.76
# median_4_dow5_2017: 1396.96
# median_60_2017: 1333.62
# longitude: 1115.00
# median_4_dow6_2017: 1060.31
# sum_4_dow5_2017: 980.13
# median_4_dow1_2017: 948.83
# holiday: 938.99
# mres_60_2017: 837.60
# median_4_dow3_2017: 781.94
# day_6_2017: 696.60
# day_1_2017: 676.36
# sum_4_dow1_2017: 676.14
# sum_4_dow2_2017: 496.18
# mres_140_2017: 480.39
# res_7: 388.28
# day_13_2017: 367.82
# day_11_2017: 334.09
# sum_4_dow4_2017: 324.16
# day_2_2017: 322.86
# mres_30_2017: 304.22
# day_5_2017: 287.84
# sum_4_dow3_2017: 281.90
# median_30_2017: 276.75
# res_10_2017: 261.08
# day_3_2017: 253.21
# median_4_dow4_2017: 252.03
# res_14: 239.25
# res_7_2017: 238.07
# res_13: 233.02
# day_12_2017: 224.17
# day_9_2017: 224.02
# res_11_2017: 222.79
# day_8_2017: 213.46
# res_9_2017: 213.11
# res_14_2017: 207.00
# day_4_2017: 180.27
# median_4_dow2_2017: 177.85
# day_10_2017: 167.82
# res_6_2017: 163.00
# res_2_2017: 158.57
# res_5_2017: 127.34
# res_4_2017: 126.98
# res_1: 125.03
# res_3: 123.42
# res_13_2017: 122.95
# res_1_2017: 122.24
# res_12: 111.60
# res_8_2017: 108.31
# res_12_2017: 102.00
# res_4: 96.35
# res_2: 91.36
# res_3_2017: 90.52
# res_10: 73.60
# res_11: 67.59
# res_8: 64.37
# res_6: 58.38
# res_9: 50.83
# res_0_2017: 50.79
# res_5: 35.97
# ==================================================
# Step 37
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.478277	valid_1's l2: 0.517258
# Early stopping, best iteration is:
# [114]	training's l2: 0.470966	valid_1's l2: 0.514058
# sum_4_dow1_2017: 56740.68
# median_4_dow1_2017: 35737.86
# res_0: 8340.38
# day_13_2017: 4105.20
# day_6_2017: 4066.49
# genre: 3684.32
# median_140_2017: 3560.48
# dow: 2043.27
# latitude: 1847.00
# median_4_dow6_2017: 1174.13
# sum_4_dow0_2017: 1028.53
# longitude: 999.95
# median_4_dow0_2017: 893.68
# median_60_2017: 806.54
# day_7_2017: 798.78
# sum_4_dow2_2017: 765.30
# mres_60_2017: 727.40
# sum_4_dow6_2017: 688.97
# day_5_2017: 682.46
# holiday: 670.78
# median_4_dow2_2017: 619.71
# median_4_dow3_2017: 503.02
# median_4_dow5_2017: 455.68
# median_30_2017: 444.30
# mres_140_2017: 421.94
# sum_4_dow3_2017: 420.30
# res_14: 359.10
# day_14_2017: 357.69
# median_4_dow4_2017: 338.31
# day_1_2017: 329.51
# sum_4_dow4_2017: 329.49
# mres_30_2017: 281.02
# day_12_2017: 268.16
# day_4_2017: 251.95
# res_10_2017: 219.35
# sum_4_dow5_2017: 218.11
# day_9_2017: 209.66
# day_2_2017: 207.72
# res_13: 193.31
# day_8_2017: 191.67
# res_11: 188.88
# day_10_2017: 185.96
# res_6_2017: 169.96
# res_3_2017: 164.75
# res_8_2017: 161.97
# res_9_2017: 161.70
# res_7_2017: 158.11
# day_3_2017: 155.40
# res_1_2017: 140.96
# day_11_2017: 139.61
# res_14_2017: 132.48
# res_7: 128.64
# res_13_2017: 122.77
# res_1: 119.67
# res_5_2017: 103.00
# res_2_2017: 101.79
# res_4_2017: 93.57
# res_11_2017: 84.59
# res_0_2017: 78.10
# res_3: 69.21
# res_12_2017: 67.57
# res_4: 64.36
# res_9: 54.21
# res_2: 52.09
# res_8: 51.33
# res_6: 37.50
# res_12: 32.73
# res_10: 28.44
# res_5: 24.89
# ==================================================
# Step 38
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.476288	valid_1's l2: 0.499063
# [200]	training's l2: 0.43935	valid_1's l2: 0.494622
# Early stopping, best iteration is:
# [189]	training's l2: 0.442622	valid_1's l2: 0.493685
# sum_4_dow2_2017: 69699.80
# median_4_dow2_2017: 28194.94
# res_0: 8158.87
# genre: 4144.80
# median_140_2017: 3377.58
# day_12_2017: 2713.03
# dow: 2329.19
# latitude: 2302.50
# day_5_2017: 1951.15
# sum_4_dow0_2017: 1708.62
# sum_4_dow1_2017: 1564.50
# longitude: 1354.51
# median_4_dow0_2017: 1144.44
# median_4_dow1_2017: 1018.15
# sum_4_dow3_2017: 1007.07
# median_60_2017: 859.32
# median_4_dow3_2017: 745.52
# holiday: 717.13
# day_6_2017: 685.03
# mres_60_2017: 656.26
# day_4_2017: 616.17
# mres_140_2017: 591.54
# day_13_2017: 583.57
# sum_4_dow4_2017: 550.68
# median_4_dow6_2017: 537.07
# sum_4_dow6_2017: 456.57
# sum_4_dow5_2017: 428.78
# median_30_2017: 425.30
# median_4_dow4_2017: 403.27
# res_14: 385.83
# res_13: 314.77
# day_11_2017: 300.68
# median_4_dow5_2017: 297.73
# res_12_2017: 292.36
# day_14_2017: 285.37
# res_2_2017: 263.20
# day_1_2017: 254.25
# res_14_2017: 228.84
# mres_30_2017: 228.79
# day_2_2017: 228.43
# day_9_2017: 224.31
# day_3_2017: 220.51
# res_8_2017: 213.38
# res_7: 207.46
# res_7_2017: 205.67
# res_10_2017: 197.38
# res_9_2017: 193.30
# day_7_2017: 188.64
# res_11: 178.84
# day_10_2017: 175.88
# res_5_2017: 174.45
# res_6_2017: 170.58
# res_13_2017: 170.50
# day_8_2017: 168.57
# res_0_2017: 167.33
# res_1_2017: 167.17
# res_1: 155.47
# res_11_2017: 150.05
# res_4_2017: 149.40
# res_12: 129.09
# res_3: 126.28
# res_3_2017: 120.85
# res_4: 101.26
# res_2: 94.12
# res_5: 82.28
# res_9: 72.63
# res_6: 71.31
# res_10: 66.28
# res_8: 58.47
# ==================================================
# Step 39
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 0.4747	valid_1's l2: 0.42049
# [200]	training's l2: 0.438618	valid_1's l2: 0.416008
# Early stopping, best iteration is:
# [232]	training's l2: 0.429633	valid_1's l2: 0.413383
# sum_4_dow3_2017: 76930.96
# median_4_dow3_2017: 21682.56
# res_0: 8591.80
# genre: 4652.85
# median_140_2017: 3104.45
# dow: 2593.86
# latitude: 2352.95
# day_4_2017: 2110.72
# day_11_2017: 1831.51
# sum_4_dow2_2017: 1586.47
# longitude: 1507.05
# sum_4_dow1_2017: 1424.01
# median_60_2017: 1319.44
# median_4_dow2_2017: 1130.57
# median_4_dow1_2017: 1088.12
# holiday: 930.14
# sum_4_dow4_2017: 908.52
# median_4_dow4_2017: 845.15
# median_4_dow0_2017: 745.96
# day_3_2017: 738.97
# day_5_2017: 684.44
# sum_4_dow0_2017: 652.65
# mres_140_2017: 603.80
# sum_4_dow5_2017: 599.72
# mres_60_2017: 597.99
# sum_4_dow6_2017: 584.84
# day_12_2017: 581.53
# median_4_dow6_2017: 488.32
# res_11_2017: 428.02
# res_14: 425.73
# res_13: 388.76
# median_30_2017: 356.76
# day_10_2017: 333.43
# median_4_dow5_2017: 307.79
# res_14_2017: 293.59
# day_1_2017: 292.21
# day_13_2017: 264.21
# res_4_2017: 251.39
# day_6_2017: 250.07
# day_2_2017: 244.49
# res_12_2017: 233.02
# res_6_2017: 228.08
# res_7_2017: 195.57
# day_9_2017: 184.27
# res_11: 176.29
# res_13_2017: 175.46
# res_10: 174.71
# res_8_2017: 173.07
# res_4: 171.80
# day_14_2017: 171.21
# res_5_2017: 170.44
# res_10_2017: 165.16
# mres_30_2017: 164.01
# res_1_2017: 159.13
# day_8_2017: 155.87
# res_2_2017: 151.05
# res_3_2017: 150.60
# res_3: 149.90
# day_7_2017: 145.75
# res_7: 139.24
# res_1: 137.73
# res_9_2017: 135.67
# res_6: 124.46
# res_2: 119.50
# res_0_2017: 117.97
# res_8: 109.67
# res_12: 107.43
# res_9: 105.39
# res_5: 77.05

# %%
print("Validation mse:", mean_squared_error(
    y_val, np.array(val_pred).transpose()))
# Out:
# Validation mse: 0.5240798477282607

# %%
print("Making submission...")
y_test = np.array(test_pred).transpose()
df_preds = pd.DataFrame(y_test, index=df_train.index, columns=pd.date_range("2017-04-23", periods=39)
                       ).stack().to_frame("visitors").reset_index()
df_preds['id'] = df_preds[['air_store_id', 'level_1']].apply(lambda x: x[0] + '_' + str(x[1].date()), axis = 1)
df_preds.drop(['air_store_id', 'level_1'], axis = 1, inplace = True)
# Out:
# Making submission...

# %%
submission = sample[["id"]].merge(df_preds, how="left", left_on = 'id', right_on = 'id')
submission["visitors"] = np.clip(np.around(np.expm1(submission["visitors"])), 0, 1000)
submission["visitors"] = submission['visitors'].astype('int')
submission.to_csv('try4.csv', index=None)
